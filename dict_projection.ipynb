# %%
import pandas as pd
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['project_evaluations']

collection = db['games']

# %%
from datetime import datetime

query_docs = collection.find({
    "first_release_date": {"$gt": datetime(2024, 1, 1)},
    "steam_id": {"$exists": True, "$ne": None},
        "idg_owners_est": {"$exists": False}


})

# %%
from datetime import datetime

query_docs = collection.find({
    "idg_owners_est": {"$exists": True}})

# %%
df = pd.DataFrame(query_docs)

# %%
pd.json_normalize(df['idg_owners_est']).sum() / pd.json_normalize(df['idg_owners_est']).sum().sum()
# Out:
# Steam             0.511582
# PS4               0.192465
# XBO               0.150917
# WindowsOneCore    0.007031
# PS5               0.132695
# XBS               0.005311
# dtype: float64

# %%
owners_col = pd.json_normalize(df['idg_owners_est'])

# %%
owners_col['total_owners'] = owners_col.sum(axis=1)

# %%
owners_col / 1_000
# Out:
#         Steam    PS4    XBO  WindowsOneCore  PS5  XBS  total_owners
# 0      1164.0    NaN    NaN             NaN  NaN  NaN        1164.0
# 1      3339.0  522.0  381.0             NaN  NaN  NaN        4242.0
# 2       635.0    NaN    NaN             NaN  NaN  NaN         635.0
# 3       781.0    NaN    NaN             NaN  NaN  NaN         781.0
# 4         NaN    NaN    NaN             NaN  NaN  NaN           0.0
# ...       ...    ...    ...             ...  ...  ...           ...
# 23415     NaN    NaN    NaN             NaN  NaN  NaN           0.0
# 23416     NaN    NaN    NaN             NaN  NaN  NaN           0.0
# 23417     NaN    NaN    NaN             NaN  NaN  NaN           0.0
# 23418     NaN    NaN    NaN             NaN  NaN  NaN           0.0
# 23419     NaN    NaN    NaN             NaN  NaN  NaN           0.0
#
# [23420 rows x 7 columns]

# %%
combined = pd.concat([df, owners_col], axis=1)

# %%
combined.sort_values(by='total_owners', ascending=False).head(10)
# Out:
#           _id                              checksum  \
# 10743    1020  c099f3d2-14f0-57f3-ca2d-068855babca4
# 3420   114795  11502eeb-9ec4-0150-25ad-f6eadd255563
# 1205     1372  03ec69e8-80ed-2bb5-cc67-ec0e2245691d
# 11048   27789  b6c002d3-3ec1-7089-53cb-788bab72d896
# 5297   207393  112a8eec-f2c7-ec61-d11a-cccb9f3c13f1
# 10111   25657  27f42404-0beb-f488-5954-9f680e95f269
# 22759  119313  1b2f74be-043a-f083-c3c4-7dfe8bd12722
# 9584   256092  ea6e1e8e-274b-dc06-894e-c65d4a6f22c5
# 10755    7360  6e503017-063d-d93c-8f19-7af4aba68c64
# 22273  154986  04c7ad5a-6e0e-8719-b654-60b27d33eac8
#
#                                    name  \
# 10743                Grand Theft Auto V
# 3420                       Apex Legends
# 1205   Counter-Strike: Global Offensive
# 11048               PUBG: Battlegrounds
# 5297                           NBA 2K23
# 10111                         Destiny 2
# 22759                         Fall Guys
# 9584                    EA Sports FC 24
# ...
